# %%
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus
# %cd /content/Fooocus
# !pip install pygit2==1.12.2
# !python entry_with_update.py --share
# Out:
# /content
# fatal: destination path 'Fooocus' already exists and is not an empty directory.
# /content/Fooocus
# Requirement already satisfied: pygit2==1.12.2 in /usr/local/lib/python3.10/dist-packages (1.12.2)
# Requirement already satisfied: cffi>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from pygit2==1.12.2) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.9.1->pygit2==1.12.2) (2.21)
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share']
# Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# Fooocus version: 2.1.824
# Running on local URL:  http://127.0.0.1:7865
# Total VRAM 15102 MB, total RAM 12983 MB
# 2023-12-02 18:46:07.274115: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-02 18:46:07.274172: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-02 18:46:07.274212: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-02 18:46:09.137757: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Running on public URL: https://1ef5b86f00f9d14ed3.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Set vram state to: NORMAL_VRAM
# Disabling smart memory management
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# Refiner unloaded.
# model_type EPS
# adm 2816
# Using pytorch attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using pytorch attention in VAE
# extra keys {'cond_stage_model.clip_l.logit_scale', 'cond_stage_model.clip_g.transformer.text_model.embeddings.position_ids', 'cond_stage_model.clip_l.text_projection'}
# Base model loaded: /content/Fooocus/models/checkpoints/juggernautXL_version6Rundiffusion.safetensors
# Request to load LoRAs [['sd_xl_offset_example-lora_1.0.safetensors', 0.1], ['None', 1.0], ['None', 1.0], ['None', 1.0], ['None', 1.0]] for model [/content/Fooocus/models/checkpoints/juggernautXL_version6Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_version6Rundiffusion.safetensors] with 788 keys at weight 0.1.
# Fooocus V2 Expansion: Vocab with 642 words.
# Fooocus Expansion engine loaded for cuda:0, use_fp16 = True.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.71 seconds
# App started successful. Use the app with http://127.0.0.1:7865/ or 127.0.0.1:7865 or https://1ef5b86f00f9d14ed3.gradio.live
# [Parameters] Adaptive CFG = 7
# [Parameters] Sharpness = 2
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] CFG = 4.0
# [Parameters] Seed = 8159143972825981887
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Request to load LoRAs [['pytorch_lora_weights.safetensors', 0.1], ['pytorch_lora_weights.safetensors', 1.0], ['None', 1.0], ['None', 1.0], ['None', 1.0]] for model [/content/Fooocus/models/checkpoints/juggernautXL_version6Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/pytorch_lora_weights.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_version6Rundiffusion.safetensors] with 560 keys at weight 0.1.
# Loaded LoRA [/content/Fooocus/models/loras/pytorch_lora_weights.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_version6Rundiffusion.safetensors] with 560 keys at weight 1.0.
# Requested to load SDXLClipModel
# Loading 1 new model
# unload clone 1
# [Fooocus Model Management] Moving model(s) has taken 1.17 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] Genera una imagen de Devsys vestido elegante con sus gafas y con barba, surreal, sharp focus, extremely detailed, intricate, cinematic light, innocent, positive dynamic dramatic color, quality, highly detail, joyful, magical atmosphere, cute, engaging, silent, scientific, artistic, fine frank, created inspired, perfect composition, beautiful, elegant
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] Genera una imagen de Devsys vestido elegante con sus gafas y con barba, glowing, magical, radiant, highly detailed, professional quality, mystical, scientific, mythical, magic, dramatic, sharp focus, extremely detail, artistic, innocent, fair, aesthetic, exciting, thought, full color, iconic, fine, epic composition, amazing dynamic
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.11 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 7.19 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.50 seconds
# 100% 30/30 [00:28<00:00,  1.06it/s]
# Image generated with private log at: /content/Fooocus/outputs/2023-12-02/log.html
# Generating and saving time: 35.27 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.06 seconds
# 100% 30/30 [00:25<00:00,  1.17it/s]
# Image generated with private log at: /content/Fooocus/outputs/2023-12-02/log.html
# Generating and saving time: 31.93 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 1.21 seconds
# Total time: 79.03 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] Sharpness = 2
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] CFG = 4.0
# [Parameters] Seed = 1434543295236918541
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] Genera una imagen de Devsys joven, vibrant colors, intricate, highly detailed, impressive, magical atmosphere, magic, full background, cinematic, dynamic, majestic, pristine, beautiful, optimistic, unique, very inspirational, colorful, illuminated, perfect composition, symmetry, clear, aesthetic, charming, marvelous, pure, fine detail, pretty, attractive, artistic
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] Genera una imagen de Devsys joven, intricate, elegant, highly detailed, wonderful colors, sweet, sharp focus, clear background, divine, cinematic, symmetry, dramatic ambient, artistic, fine detail, professional, joyful, sublime, cool, expressive, cute, confident, inspired, pretty, illuminated, beautiful, loving, amazing, creative, pure, positive
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 2.52 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.66 seconds
# 100% 30/30 [00:26<00:00,  1.12it/s]
# Image generated with private log at: /content/Fooocus/outputs/2023-12-02/log.html
# Generating and saving time: 33.62 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.85 seconds
# 100% 30/30 [00:26<00:00,  1.15it/s]
# Image generated with private log at: /content/Fooocus/outputs/2023-12-02/log.html
# Generating and saving time: 31.66 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.78 seconds
# Total time: 72.17 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] Sharpness = 2
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] CFG = 4.0
# [Parameters] Seed = 9211176081584065040
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] genera una imagen Devsys como super heroe, glowing rich colors amazing fine detail deep vivid color intricate stunning epic cinematic great composition, extremely dynamic dramatic ambient light, atmosphere, spectacular beautiful, sharp focus, winning awarded, shiny, fabulous, symmetry, clear quality, very inspirational, professional thought, fantastic, bright, detailed, creative, positive, wonderful, cute
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] genera una imagen Devsys como super heroe, colorful, magic, glowing, mythical, enchanted, magical, radiant, detailed, dramatic, intricate, cinematic, complex, highly, extremely detail, professional, clear, transparent, directed, rich, artistic, inspiring, thought, epic, best, original, fresh, hopeful, vivid, amazing, beautiful
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 2.22 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.77 seconds
# 100% 30/30 [00:27<00:00,  1.10it/s]
# Image generated with private log at: /content/Fooocus/outputs/2023-12-02/log.html
# Generating and saving time: 34.23 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.85 seconds
# 100% 30/30 [00:25<00:00,  1.17it/s]
# Image generated with private log at: /content/Fooocus/outputs/2023-12-02/log.html
# Generating and saving time: 31.33 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.81 seconds
# Total time: 72.28 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] Sharpness = 2
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] CFG = 4.0
# [Parameters] Seed = 4179663088740820501
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] genera una imagen Devsys de 50 años, glowing rich colors amazing composition elegant highly detailed sharp focus holy epic cinematic fine stunning surreal flowing atmosphere, extremely aesthetic, very inspirational, mystical, inspiring, noble, scientific, artistic, winning, perfect, deep color, best detail, still, full gigantic intricate great grand futuristic luxurious complex, open marvelous, awesome
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] genera una imagen Devsys de 50 años, intricate, elegant, highly detailed, wonderful atmosphere, sweet, sharp focus, cinematic, fine composition, complex, very inspirational, colorful, endowed, epic light, striking, coherent, expressive, shiny, marvelous, rich deep color, beautiful, noble, novel, pretty, stunning, brilliant, creative, amazing
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 2.18 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.58 seconds
# 100% 30/30 [00:28<00:00,  1.07it/s]
# Image generated with private log at: /content/Fooocus/outputs/2023-12-02/log.html
# Generating and saving time: 34.67 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.59 seconds
# 100% 30/30 [00:25<00:00,  1.17it/s]
# Image generated with private log at: /content/Fooocus/outputs/2023-12-02/log.html
# Generating and saving time: 32.13 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.79 seconds
# Total time: 73.40 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] Sharpness = 2
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] CFG = 4.0
# [Parameters] Seed = 9122561821700610240
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] genera una imagen Devsys como super heroe y dejale las gafas, colorful, magic, glowing, vivid, detailed, atmosphere, gorgeous, intricate, shiny, highly shining, clear, color, strong, cinematic, dynamic, full light, professional, winning, best, artistic, dramatic, beautiful, elegant, deep colors, perfect
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] genera una imagen Devsys como super heroe y dejale las gafas, intricate, elegant, highly detailed, sharp focus, majestic, new, amazing, epic, cinematic, directed, symmetry, fine, ambient, bright, crisp, shiny, shining, heroic, rich, colorful, great, open atmosphere, iconic, extremely, fantastic
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 2.00 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.57 seconds
# 100% 30/30 [00:27<00:00,  1.10it/s]
# Image generated with private log at: /content/Fooocus/outputs/2023-12-02/log.html
# Generating and saving time: 33.94 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.83 seconds
# 100% 30/30 [00:25<00:00,  1.16it/s]
# Image generated with private log at: /content/Fooocus/outputs/2023-12-02/log.html
# Generating and saving time: 32.71 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.83 seconds
# Total time: 72.95 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] Sharpness = 2
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] CFG = 4.0
# [Parameters] Seed = 7570378251017050257
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] genera una imagen Devsys como super heroe y dejale las gafas con lente transparente que lleva aveces, glowing, vivid, highly detailed, futuristic, magical, professional, cinematic, dramatic, sharp focus, breathtaking, magic, deep background, excellent composition, dynamic light, atmosphere, great detail, creative, positive
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] genera una imagen Devsys como super heroe y dejale las gafas con lente transparente que lleva aveces, surreal, highly detailed, sharp focus, ambient light, sublime, radiant, magic, full color, elegant, intricate, very inspirational, glowing, rich deep colors, beautiful epic cinematic composition, dramatic professional fine
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 1.71 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.74 seconds
# 100% 30/30 [00:26<00:00,  1.11it/s]
# Image generated with private log at: /content/Fooocus/outputs/2023-12-02/log.html
# Generating and saving time: 33.83 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.87 seconds
# 100% 30/30 [00:25<00:00,  1.16it/s]
# Image generated with private log at: /content/Fooocus/outputs/2023-12-02/log.html
# Generating and saving time: 31.62 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.82 seconds
# Total time: 71.44 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] Sharpness = 2
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] CFG = 4.0
# [Parameters] Seed = 4873342416402920961
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] genera una imagen Devsys como un religioso, dramatic ambient light, highly detailed, sharp focus, aesthetic, dynamic, cinematic, great composition, bright colors, elegant, perfect, intricate, complex, glowing, amazing detail, professional background, best, creative, positive, thoughtful, vibrant, beautiful, confident, unique, passionate, cute, friendly
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] genera una imagen Devsys como un religioso, detailed, blazing new light, flowing divine magic, professional, artistic, charismatic, beautiful, dramatic, lucid, intricate, fabulous, wonderful, glowing, magical, colorful, infinite, shiny, brilliant, highly, epic, singular, coherent, lovely, perfect, amazing, creative, pure, marvelous
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 2.18 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.59 seconds
# 100% 30/30 [00:26<00:00,  1.14it/s]
# Image generated with private log at: /content/Fooocus/outputs/2023-12-02/log.html
# Generating and saving time: 33.13 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.54 seconds
#  97% 29/30 [00:26<00:00,  1.11it/s]
# User stopped
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 66.11 seconds
# [Fooocus Model Management] Moving model(s) has taken 2.47 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] Sharpness = 2
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] CFG = 4.0
# [Parameters] Seed = 5303369162438672987
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] Quien es el mejor?, detailed, expansive, exquisite detail, warm colors, beautiful, gorgeous, epic, best, cinematic, sharp focus, colorful, great composition, elegant, perfect calm, aesthetic, highly educated, professional, smart, rich, color, illuminated, determined, cool, friendly, vibrant, passionate, pretty, cute, creative,, inspirational
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] Quien es el mejor?, pretty, highly detailed, professional, quality, refined, burning background, deep aesthetic, very inspirational, beautiful, emotional, shiny, vibrant, enchanted, colorful, inspired, rich vivid colors, fine detail, elaborate, complex, color, enhanced, symmetry, light, divine, clear, crisp, extremely sharp, coherent, intricate, glorious
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 2.32 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.46 seconds
#  90% 27/30 [00:23<00:02,  1.11it/s]Keyboard interruption in main thread... closing server.
# 100% 30/30 [00:26<00:00,  1.14it/s]
# Image generated with private log at: /content/Fooocus/outputs/2023-12-02/log.html
# Generating and saving time: 32.71 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.64 seconds
#  17% 5/30 [00:04<00:22,  1.11it/s]
